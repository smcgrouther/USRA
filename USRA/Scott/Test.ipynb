# %%
#IMPORTING

source("Gaussian.r")
source("Gamma.r")
source("Beta.r")
source("Loss.r")

# %%
# BETA

valuez = c(0.25, 0.5, 0.75,1.25,1,1.5,2,2.5)

for (value in valuez) {
    print(find_rho_gamma(0.05, 1, value, Inf, 0.01))
}

print("--------------------------------------------")

for (value in valuez) {
    print(find_rho_ph(0.05, value, 0.01))
}

print("--------------------------------------------")

for (i in 1:7){
    
    print(find_rho_beta(0.05,valuez[i], valuez[i],0.01))
}

print("--------------------------------------------")

valuez2 <- c(2.5,2,1.5,1,1.25,0.75, 0.5,0.25)
for (i in 1:8){
    
    print(find_rho_beta(0.05,valuez[i], valuez2[i],0.01))
}
# Out:
# [1] 0.3127788
# [1] 0.3133695
# [1] 0.313953
# [1] 0.3150637
# [1] 0.3145189
# [1] 0.3155866
# [1] 0.3165694
# [1] 0.3174759
# [1] "--------------------------------------------"
# [1] 0.07615194
# [1] 0.1517332
# [1] 0.2309204
# [1] 0.4013973
# [1] 0.3145189
# [1] 0.4884365
# [1] 0.6513958
# [1] 0.7746769
# [1] "--------------------------------------------"
# [1] 0.06643421
# [1] 0.1446028
# [1] 0.2285152
# [1] 0.4000435
# [1] 0.3145189
# [1] 0.4828193
# [1] 0.6309702
# [1] "--------------------------------------------"
# [1] 0.0816396
# [1] 0.1591549
# [1] 0.2346139
# [1] 0.4013973
# [1] 0.3150637
# [1] 0.4917791
# [1] 0.657896
# [1] 0.7746441

# %%
# Gaussian

valuez <- c(-6,-4,-2,0,2,4,6)

for (value in valuez){
    print(find_rho_gaussian(0.05,value,1,0.01))
}

print("--------------------------------------------")

valuez2 <- c(0.25, 0.5,0.75,1,1.25,1.5,1.75)

for (value in valuez2){
    print(find_rho_gaussian(0.05,0, value,0.01))
}

print("--------------------------------------------")

for (i in 1:7){
    
    print(find_rho_gaussian(0.05,valuez[i], valuez2[i],0.01))
}

print("--------------------------------------------")

valuez2 <- c(1.75,1.5,1.25,1,0.75,0.5,0.25)
for (i in 1:7){
    
    print(find_rho_gaussian(0.05,valuez[i], valuez2[i],0.01))
}
# Out:
# [1] 0.08681426
# [1] 0.1086567
# [1] 0.1604132
# [1] 0.3145189
# [1] 0.6262661
# [1] 0.8111285
# [1] 0.8856122
# [1] "--------------------------------------------"
# [1] 0.9821162
# [1] 0.8774192
# [1] 0.5351177
# [1] 0.3145189
# [1] 0.2041682
# [1] 0.1428022
# [1] 0.1053635
# [1] "--------------------------------------------"
# [1] 0.857264
# [1] 0.2607945
# [1] 0.2362084
# [1] 0.3145189
# [1] 0.4091716
# [1] 0.4439826
# [1] 0.4431595
# [1] "--------------------------------------------"
# [1] 0.04024201
# [1] 0.06279311
# [1] 0.1159757
# [1] 0.3145189
# [1] 0.8570234
# [1] 0.975745
# [1] "Root finding with initial bounds failed. Trying with reduced integration bounds.  May need to change manually within the code as it is hard fixed bounds if there is still an error."
# [1] 0.9999324
